# %% [markdown]
# ## INSTALL LIBRARY

# %%
# !pip install scikit-learn
# !pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 6.3 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=ddc53343a67f508955f078415d3978fe91da4caf2c07f81f216d2861ed89073b
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
# !pip install langdetect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 981 kB 6.7 MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=d595ffe44896c5f048fd27c2499ca03f6cbb60e4bb318b6ece51f34fd3e12222
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# ...

# %%
# !pip install eli5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 216 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 133 kB 45.4 MB/s
# ...
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107748 sha256=2a528571cf308ef08db25009ff30f59576332c63a871ab07d423eff9925e7736
#   Stored in directory: /root/.cache/pip/wheels/cc/3c/96/3ead31a8e6c20fc0f1a707fde2e05d49a80b1b4b30096573be
# Successfully built eli5
# ...
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# ...

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tweepy stylecloud -q
# Out:
#      |████████████████████████████████| 262 kB 6.4 MB/s
#      |████████████████████████████████| 161 kB 49.9 MB/s
#      |████████████████████████████████| 87 kB 6.5 MB/s
#      |████████████████████████████████| 87 kB 5.6 MB/s
# ...

# %%
pip install vaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 8.5 MB/s
# ...

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 16.5 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 65 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.9 MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17416 sha256=c0bb78415f7a49372cd0f467193d3b6dec40227da6f4b23a41a0e30d0016a75d
#   Stored in directory: /root/.cache/pip/wheels/43/34/00/4fe71786ea6d12314b29037620c36d857e5d104ac2748bf82a
# Successfully built googletrans
# ...

# %%
! pip install -U textblob
! python -m textblob.download_corpora
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 636 kB 7.5 MB/s
# ...
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.15.3
#     Uninstalling textblob-0.15.3:
#       Successfully uninstalled textblob-0.15.3
# ...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# ...

# %% [markdown]
# ##IMPORT LIBRARY

# %% [markdown]
# import usually use library

# %% [markdown]
# import tweepy
# from textblob import TextBlob
# from wordcloud import WordCloud
# import pandas as pd
# import numpy as np
# import re
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.style.use('fivethirtyeight')
# from sklearn.model_selection import train_test_split

# %% [markdown]
# import odd library

# %%
from wordcloud import WordCloud

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split

# %%
import time
import traceback

# %% [markdown]
# Add library to download files

# %%
from google.colab import files

# %% [markdown]
# Translate

# %%
from langdetect import detect

# %%
import nltk
nltk.download('stopwords')
nltk.download('omw-1.4')
from nltk import word_tokenize, pos_tag, pos_tag_sents
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
import vaderSentiment

# %%
from nltk.corpus import stopwords

# %%
from collections import Counter

# %% [markdown]
# Style wordcloud

# %%
import stylecloud

# %% [markdown]
# TF- IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from itertools import islice

# %% [markdown]
# Textblob

# %%
from textblob import TextBlob

# %% [markdown]
# # TWITTER'S USER REACTION

# %% [markdown]
# ## Database

# %% [markdown]
# ### Import Database

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TwtAPI.xlsx')

# %% [markdown]
# Drop unnamed column

# %%
df.rename({"Unnamed: 0":"1"}, axis="columns", inplace=True)
df.drop(["1"], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user_name         10000 non-null  object
#  1   user_location     7112 non-null   object
#  2   user_description  8944 non-null   object
#  3   user_verified     10000 non-null  bool
#  4   date              10000 non-null  datetime64[ns]
#  5   text              10000 non-null  object
#  6   hashtags          880 non-null    object
#  7   source            10000 non-null  object
# dtypes: bool(1), datetime64[ns](1), object(6)
# memory usage: 556.8+ KB

# %%
import missingno

missingno.bar(df, figsize=(10,5), fontsize=12);

# %% [markdown]
# customize df

# %%
df_db = df[['text']]
df_db
# Out:
#                                                    text
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 4     RT @MuneerahSuraj: Customized phone cases:\nSa...
# ...                                                 ...
# 9995  RT @CurrenSy_Spitta: If I had an iPhone with g...
# 9996  RT @EbukaIsaac26: Johnny Drille and Don Jazzy ...
# 9997  RT @Crunchyroll: w00t apple just announced the...
# 9998  Have you been searching for the best corporate...
# 9999  RT @bidemi42: Dear Nigerians.\npls help retwee...
#
# [10000 rows x 1 columns]

# %% [markdown]
# Check and Remove all duplicated Tweets

# %%
df_db.duplicated().sum()
# Out:
# 5713

# %%
df_db.drop_duplicates(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# ## EDA

# %% [markdown]
# #### LANGUAGE CLEANING

# %%
df_db['language'] = df_db['text'].apply(detect)
df_db['language'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# en    4086
# tl      19
# fr      19
# de      18
# so      15
# et      14
# it      14
# da      12
# no      12
# id      10
# ja       8
# af       7
# hr       6
# nl       6
# ro       5
# pl       5
# fi       4
# sw       4
# sl       4
# cy       3
# ca       3
# sv       3
# vi       2
# th       2
# sk       1
# sq       1
# pt       1
# hu       1
# ar       1
# es       1
# Name: language, dtype: int64

# %%
# choose only English Tweets
df_db = df_db[df_db['language'] == 'en']

# %% [markdown]
# Word display

# %%
#1. Total No of Char
df_db['num_char'] = df_db['text'].apply(len)
#2. Total No of Words
df_db['num_words'] = df_db['text'].apply(lambda x: len(str(x).split()))
#3. avg word length
df_db['avg_words_length'] = df_db['num_char']/df_db['num_words']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_db
# Out:
#                                                    text language  num_char  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...       en       139
# 1     RT @discount77777: Get Free iPhone Giveaway ht...       en       139
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...       en       140
# 3     RT @shopapplegh: We have these in stock today....       en       111
# 4     RT @MuneerahSuraj: Customized phone cases:\nSa...       en       137
# ...                                                 ...      ...       ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...       en       104
# 9982  December is not a deadline to be rich no go le...       en       128
# 9987  Best free antivirus for iPhone \nData is the n...       en       235
# 9988  RT @ianzelbo: I have the sudden urge to buy an...       en        56
# 9989  Love is Love LGBT Gay Pride Digital Download P...       en       297
#
#       num_words  avg_words_length
# ...

# %%
sns.set(rc={"figure.figsize":(20, 10)})
sns.boxplot(data=df_db[["num_char", "num_words","avg_words_length"]], orient="v", width=0.5)

# %% [markdown]
# #### Outliner

# %%
# IQR
Q1 = np.percentile(df_db['num_char'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df_db['num_char'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
print("Inter Quartile Range:",IQR)
print("Upper fence:", Q3+1.5*IQR)
# Out:
# Inter Quartile Range: 89.5
# Upper fence: 302.75

# %%
# IQR
Q1 = np.percentile(df_db['num_words'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df_db['num_words'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
print("Inter Quartile Range:",IQR)
print("Upper fence:", Q3+1.5*IQR)
# Out:
# Inter Quartile Range: 15.0
# Upper fence: 49.5

# %%
# IQR
Q1 = np.percentile(df_db['avg_words_length'], 25, interpolation = 'midpoint')
Q3 = np.percentile(df_db['avg_words_length'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
print("Inter Quartile Range:",IQR)
print("Upper fence:", Q3+1.5*IQR)
print("Lower fence:", Q1-1.5*IQR)
# Out:
# Inter Quartile Range: 1.8932432432432442
# Upper fence: 10.33310810810811
# Lower fence: 2.7601351351351333

# %%
df_db.loc[df_db.num_char > 304.0]
# Out:
#                                                    text language  num_char  \
# 268   @Varun_dvn @kritisanon @Deepakyahanhai @nowits...       en       393
# 394   @jbknight13 @SarahKi71751078 @RSBNetwork I dic...       en       305
# 628   @sarcasticmodi @_harxxn @geekyranjit @sikonmis...       en       319
# 1218  @hasanyahya04 @J3SV1N @sondesix Because the iP...       en       305
# 1222  MySon was watching videos on YouTube I gotAMas...       en       311
# 1232  @METROFMSA @CapitecBankSA MySon was watching v...       en       313
# 1263  MySon was watching videos on YouTube I got aMa...       en       311
# 1601  @Walms_eth @TalesfrM @DavidYuNZ Wen did us AME...       en       307
# 1756  Brand new iPhones available \nwe courier natio...       en       322
# 2063  @BrianMickelson @tim_cook Introducing differen...       en       305
# 2156  @BrianMickelson @tim_cook When I am using usin...       en       305
# ...

# %%
df_db.loc[df_db.num_words > 49.5]
# Out:
#                                                    text language  num_char  \
# 87    @BrianMickelson @tim_cook Sure enjoy running j...       en       304
# 172   I remember by @Apple ID password, but when I l...       en       277
# 286   @imbackbitches68 @AdamKinzinger STOPPED COUNTI...       en       296
# 367   @ElimzzTV_ @OfficiaIDevour Honestly I think bo...       en       273
# 394   @jbknight13 @SarahKi71751078 @RSBNetwork I dic...       en       305
# ...                                                 ...      ...       ...
# 9647  @amazon @amazonIN @JeffBezos @AmazonHelp got a...       en       249
# 9725  @kekere_ekun0 @Muizkah1 @instablog9ja Take hea...       en       317
# 9783  iPhone XS Max || 64gb || factory unlocked || b...       en       298
# 9922  Get the best iPhones when you buy a brand new ...       en       302
# 9967  @JioMart , an iPhone ordered on 2nd oct , usin...       en       276
#
#       num_words  avg_words_length
# ...

# %%
df_db.loc[df_db.avg_words_length > 10.305934195064632]
# Out:
#                                                    text language  num_char  \
# 4     RT @MuneerahSuraj: Customized phone cases:\nSa...       en       137
# 12    RT @bawcode: iphone 12                        ...       en        88
# 249   My new #iPhone14 #JaiShriMahaKaal https://t.co...       en        57
# 282   @InfiniteILLest https://t.co/zI2mSqqIBy\n\nPle...       en        94
# 445   @lil_enrique_ @TrollHugger @stupidtrashboy @SJ...       en        84
# ...                                                 ...      ...       ...
# 9346  Yellow Lungs @LoveLeamington @leamcourier @lea...       en       152
# 9538  Swan Canal #oegstgeest #netherlands #swans #ca...       en       155
# 9642                              @Strawb_belief iphone       en        21
# 9728  Aesthetic Halloween iPhone Wallpaper | Minimal...       en       300
# 9837  Got flitaa yet? \n\nhttps://t.co/MISDA8ymJc\n\...       en       120
#
#       num_words  avg_words_length
# ...

# %%
df_db.loc[df_db.avg_words_length <= 2.7764394829612207]
# Out:
# Empty DataFrame
# Columns: [text, language, num_char, num_words, avg_words_length]
# Index: []

# %%
df_db = df_db.loc[df_db.avg_words_length <= 10.305934195064632]

# %%
# add result to a new dataframe
df = df_db.drop(['language','num_char','num_words','avg_words_length'], axis=1)
df
# Out:
#                                                    text
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 5     RT @_Mashudu_M: Symptoms of forcing things \n\...
# ...                                                 ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...
# 9982  December is not a deadline to be rich no go le...
# 9987  Best free antivirus for iPhone \nData is the n...
# 9988  RT @ianzelbo: I have the sudden urge to buy an...
# 9989  Love is Love LGBT Gay Pride Digital Download P...
#
# [3987 rows x 1 columns]

# %% [markdown]
# #### Display

# %% [markdown]
# ## Pre-Processing

# %% [markdown]
# ### Cleaning

# %% [markdown]
# ### Creating a new function to Delete special symbol/ word

# %%
def cleanTxt(text):
  text = re.sub(r'(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)','',text) #remove mention
  text = re.sub(r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", '', text) #remove hashtag
  text = re.sub(r'RT[\s]+', '', text) #remove RT
  text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text) #remove link
  text = re.sub(r'[,\.?!:_]', '', text) #remove punctuations
  text = re.sub('\n', '', text)

  return text

# %%
df['text_clean']=df['text'].apply(cleanTxt)

# %%
df['text_clean'] = df['text_clean'].apply(lambda x : x.lower())

# %%
df
# Out:
#                                                    text  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 5     RT @_Mashudu_M: Symptoms of forcing things \n\...
# ...                                                 ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...
# 9982  December is not a deadline to be rich no go le...
# 9987  Best free antivirus for iPhone \nData is the n...
# 9988  RT @ianzelbo: I have the sudden urge to buy an...
# 9989  Love is Love LGBT Gay Pride Digital Download P...
#
#                                              text_clean
# 0     the iphone 14 pro max camera is garbage makes ...
# 1     get free iphone giveaway only people of france...
# 2     hurry the amazongreatindianfestival is ending ...
# 3     we have these in stock todayiphone 13 pro and ...
# ...

# %% [markdown]
# ### Customize Cleaning

# %% [markdown]
# #####Custome library

# %%
apostrophe_dict = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have",
"apple’s":"apple is",
"dxomark's":"dxomark is"
}
apostrophe_dict
# Out:
# {"ain't": 'am not / are not',
#  "aren't": 'are not / am not',
#  "can't": 'cannot',
#  "can't've": 'cannot have',
#  'cause': 'because',
#  "could've": 'could have',
#  "couldn't": 'could not',
#  "couldn't've": 'could not have',
#  "didn't": 'did not',
#  "doesn't": 'does not',
#  "don't": 'do not',
#  "hadn't": 'had not',
#  "hadn't've": 'had not have',
#  "hasn't": 'has not',
#  "haven't": 'have not',
#  "he'd": 'he had / he would',
#  "he'd've": 'he would have',
#  "he'll": 'he shall / he will',
#  "he'll've": 'he shall have / he will have',
#  "he's": 'he has / he is',
#  "how'd": 'how did',
#  "how'd'y": 'how do you',
#  "how'll": 'how will',
#  "how's": 'how has / how is',
#  "i'd": 'I had / I would',
#  "i'd've": 'I would have',
#  "i'll": 'I shall / I will',
#  "i'll've": 'I shall have / I will have',
#  "i'm": 'I am',
#  "i've": 'I have',
#  "isn't": 'is not',
#  "it'd": 'it had / it would',
#  "it'd've": 'it would have',
#  "it'll": 'it shall / it will',
# ...

# %%
short_word_dict = {
"121": "one to one",
"1/2":"half",
"adn": "any day now",
"afaik": "as far as I know",
"afk": "away from keyboard",
"aight": "alright",
"alol": "actually laughing out loud",
"b4": "before",
"b4n": "bye for now",
"bak": "back at the keyboard",
"bta": "but then again",
"btw": "by the way",
"cid": "crying in disgrace",
"cnp": "continued in my next post",
"cyo": "see you online",
"dbau": "doing business as usual",
"fud": "fear, uncertainty, and doubt",
"fwiw": "for what it's worth",
"fyi": "for your information",
"g": "grin",
"g2g": "got to go",
"ga": "go ahead",
"gal": "get a life",
"gf": "girlfriend",
"gfn": "gone for now",
"gmbo": "giggling my butt off",
"gmta": "great minds think alike",
"h8": "hate",
"hagn": "have a good night",
"hdop": "help delete online predators",
"iac": "in any case",
"ianal": "I am not a lawyer",
"ic": "I see",
"idk": "I don't know",
"imao": "in my arrogant opinion",
"imnsho": "in my not so humble opinion",
"imo": "in my opinion",
"iow": "in other words",
"ipn": "I’m posting naked",
"irl": "in real life",
"jk": "just kidding",
"l8r": "later",
"ldr": "long distance relationship",
"llta": "lots and lots of thunderous applause",
"lmao": "laugh my ass off",
"lol": "laugh out loud",
"ltr": "longterm relationship",
"luv": "love",
"m/f": "male or female",
"m8": "mate",
"milf": "mother I would like to fuck",
"oll": "online love",
"omg": "oh my god",
"otoh": "on the other hand",
"pir": "parent in room",
"ppl": "people",
"r": "are",
"rpg": "role playing games",
"ru": "are you",
"shid": "slaps head in disgust",
"somy": "sick of me yet",
"sot": "short of time",
"thanx": "thanks",
"thx": "thanks",
"u": "you",
"ur": "you are",
"uw": "you’re welcome",
"wb": "welcome back",
"wfm": "works for me",
"wibni": "wouldn't it be nice if",
"wtf": "what the fuck",
"wtg": "way to go",
"wtgp": "want to go private",
"ym": "young man",
"gr8": "great",
"etc":"et cetera"
}

# %%
icon_lib = {
    "🤣":"laugh",
    "💔":"hate",
    "😌":"pleased",
    "😂":"funny",
    "🤔":"think",
    "✅":"yes",
    "🗿":"speechless",
    "🙏🏿":"please",
    "🤩":"delighted",
    "🔥":"hot",
    "😭":"cry",
    "⚡️":"fast",
    "❤️":"love",
    "😊":"happy",
    "🥰":"thanks",
    "😢":"unfortunate",
    "☹️":"sad",
    "❌":"never",
    "👍🏻":"okay",
    "💥":"hot",
    "💸":"expensive",
    "💯":"nice",
    "😒":"disappointed",
    "🤯":"surprised",
    "🤲🏿":"want",
    "😂":"hilarious",
    "🥳":"celebrate",
    "🙂":"normal",
    "😩":"no"
}

# %% [markdown]
# #### Proceed

# %%
def lookup_dict(text, dictionary):
    for word in text.split():
        if word.lower() in dictionary:
            if word.lower() in text.split():
                text = text.replace(word, dictionary[word.lower()])
    return text

# %%
df['text_clean'] = df['text_clean'].apply(lambda x: lookup_dict(x,apostrophe_dict))
df['text_clean'] = df['text_clean'].apply(lambda x: lookup_dict(x,icon_lib))
df['text_clean'] = df['text_clean'].apply(lambda x: lookup_dict(x,short_word_dict))
df
# Out:
#                                                    text  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 5     RT @_Mashudu_M: Symptoms of forcing things \n\...
# ...                                                 ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...
# 9982  December is not a deadline to be rich no go le...
# 9987  Best free antivirus for iPhone \nData is the n...
# 9988  RT @ianzelbo: I have the sudden urge to buy an...
# 9989  Love is Love LGBT Gay Pride Digital Download P...
#
#                                              text_clean
# 0     the iphone 14 pro max camera is garbage makes ...
# 1     get free iphone giveaway only people of france...
# 2     hurry the amazongreatindianfestival is ending ...
# 3     we have these in stock todayiphone 13 pro and ...
# ...

# %% [markdown]
# ### Tokenizer

# %%
# Creating token for the clean tweets
df['tweet_token'] = df['text_clean'].apply(lambda x: word_tokenize(x))
df
# Out:
#                                                    text  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 5     RT @_Mashudu_M: Symptoms of forcing things \n\...
# ...                                                 ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...
# 9982  December is not a deadline to be rich no go le...
# 9987  Best free antivirus for iPhone \nData is the n...
# 9988  RT @ianzelbo: I have the sudden urge to buy an...
# 9989  Love is Love LGBT Gay Pride Digital Download P...
#
#                                              text_clean  \
# 0     the iphone 14 pro max camera is garbage makes ...
# 1     get free iphone giveaway only people of france...
# 2     hurry the amazongreatindianfestival is ending ...
# 3     we have these in stock todayiphone 13 pro and ...
# ...

# %% [markdown]
# Stopword

# %%
stop = stopwords.words('english')

# %%
print(stop)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
df['tweet_token'] = df['tweet_token'].apply(lambda x: [word for word in x if not word in stop])
df
# Out:
#                                                    text  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...
# 1     RT @discount77777: Get Free iPhone Giveaway ht...
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...
# 3     RT @shopapplegh: We have these in stock today....
# 5     RT @_Mashudu_M: Symptoms of forcing things \n\...
# ...                                                 ...
# 9980  New iPhone Mount with MagSafe from Belkin desi...
# 9982  December is not a deadline to be rich no go le...
# 9987  Best free antivirus for iPhone \nData is the n...
# 9988  RT @ianzelbo: I have the sudden urge to buy an...
# 9989  Love is Love LGBT Gay Pride Digital Download P...
#
#                                              text_clean  \
# 0     the iphone 14 pro max camera is garbage makes ...
# 1     get free iphone giveaway only people of france...
# 2     hurry the amazongreatindianfestival is ending ...
# 3     we have these in stock todayiphone 13 pro and ...
# ...

# %% [markdown]
# ### POS tagging

# %%
df['tagged'] = df['tweet_token'].apply(nltk.pos_tag)

# %%
print(df['tagged'].tolist())
# Out:
# [[('iphone', 'NN'), ('14', 'CD'), ('pro', 'JJ'), ('max', 'FW'), ('camera', 'NN'), ('garbage', 'NN'), ('makes', 'VBZ'), ('dog', 'JJ'), ('look', 'VB'), ('old', 'JJ'), ('handsome', 'JJ'), ('look', 'NN'), ('hard', 'JJ'), ('hes', 'NNS'), ('trying', 'VBG'), ('look', 'NN')], [('get', 'VB'), ('free', 'JJ'), ('iphone', 'NN'), ('giveaway', 'NN'), ('people', 'NNS'), ('franceswedennorwaydenmarkaustralia', 'VBP'), ('eligible', 'JJ')], [('hurry', 'NN'), ('amazongreatindianfestival', 'NN'), ('ending', 'VBG'), ('soonheres', 'NNS'), ('chance', 'NN'), ('win', 'VBP'), ('amazon', 'IN'), ('voucher', 'JJR'), ('worth', 'NN'), ('inr', 'VBZ'), ('5000comment', 'CD')], [('stock', 'NN'), ('todayiphone', 'NN'), ('13', 'CD'), ('pro', 'JJ'), ('series', 'NN'), ('3', 'CD'), ('dms', 'NN'), ('open', 'JJ')], [('mashudum', 'NN'), ('symptoms', 'NNS'), ('forcing', 'VBG'), ('things', 'NNS'), ('1', 'CD'), ('iphone', 'NN'), ('6', 'CD')], [('dubai', 'NN'), ('mall', 'NN'), ('iphone', 'NN'), ('14', 'CD'), ('pro', 'JJ'), ('512gb
# ...

# %%
df['sentiment'] = df['tagged'].apply(lambda x: [word for word, tag in x if tag in ['NN', 'NNS','VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ','RB','RBR','RBS','MD','JJ','JJR','JJS','PDT','RP','UH','WDT','WRB','WP']])

# %% [markdown]
# ###Lemmatizer

# %%
df['lemmatized'] = df['sentiment'].apply(lambda x: ' '.join([lemmatizer.lemmatize(i,pos="a") for i in x]))

# %%
#Remove irrelevant values
more_stop = ['iphone','pro','max','phone','apple','people','x','xs','xr','samsung','twitter','ipad','todayiphone','franceswedennorwaydenmarkaustralia','amazongreatindianfestival','s10s10s20s20n3500iphone','casessamsung','seriesn3500','n3500','promax','xsmax','iphone14pro','iphone14promax','iphone14','askurvashi','jerusalem','imran','khanballondorbtsarmy','android','wallpapers','truvybe','truvyberadio','app','amp','im','cybernipo','etsyseller','io','wed','oct','camera','user','users','video','way','ios','radio','mobile']
df['comment_word_token'] = df['lemmatized'].apply(lambda x: ' '.join([word for word in x.split() if word not in (more_stop)]))

# %%
print(df['comment_word_token'].tolist())
# Out:
# ['garbage makes dog look old handsome look hard hes trying look', 'get free giveaway eligible', 'hurry ending soonheres chance win voucher worth inr', 'stock series dms open', 'mashudum symptoms forcing things', 'dubai mall gold available available time', 'international smartphone giveaway officially started best luck everyone entering first round win', 'anyone want giving away hours lucky follower enter raffle fo', 'millions new artists need onboarded rndr much simple desktop tools currently offer rndr baked design new believe address', 'today years old learned trick', 'notch fucking ugly laugh ass shit', 'mirror selfie best taste bbs armpit involved aha', 'hio hapo chini imeandkwa', 'usbc female lightening would good least need carry separate chargers would eliminated', 'cellphone technology peaked flip phones could turn select fire pistolthe could never', 'wallpaper lens new download', 'playing thandi ntuli cosmic lighttruvybe download today', 'belief booty expire need', 'ishmael 
# ...

# %%
df_new = df[['text','comment_word_token']]

# %%
df_train, df_test = train_test_split(df_new, test_size=0.2)

# %%
df = df_train
df
# Out:
#                                                    text  \
# 3940  @olami133 Person wey load HP 180k and Iphone d...
# 3855  RT @vampireinfinite: How to Send a Text From a...
# 9472  Almost 1 Million People in Chinese City Near i...
# 5281  @od_young @ama_kodesh Joker... iPhone users an...
# 65    RT @Ahmadansari2233: ⬇️⬇️Home screen setup fo ...
# ...                                                 ...
# 6819  RT @Blacktradelines: 6 foot iPhone cable - $5....
# 7487  RT @OmuhimaGd: 3cows or an iphone 14promax \nW...
# 138   @messipropfc @uhd2020 I used a humble now “old...
# 4229  On my iPhone 8 the Monkey application starts i...
# 435   Well, @heatherkelly has tackled America's grea...
#
#                                      comment_word_token
# 3940     person wey load hp dey follow palmpay drag mad
# 3855  send text computer phonehowto tipster tipsandt...
# 9472               almost chinese city factory lockdown
# 5281  young kodesh joker empty talkingao ask fold co...
# ...

# %%
df_test
# Out:
#                                                    text  \
# 7848  @Neliswa_Nelli I ignored him but started panic...
# 3700  Have the freedom to sell your products and ser...
# 8277  Apple to launch a foldable iPad rather than iP...
# 1218  @hasanyahya04 @J3SV1N @sondesix Because the iP...
# 315   Miley Cyrus swallows Grammy Award”, “iphone”, ...
# ...                                                 ...
# 8444  @PrezzVerde @sambitswaraj Here is the excuse अ...
# 4634  RT @O_R_atsu: iPhone pic \n#art #photography #...
# 1437  RT @notromeosgirl: This hottie or iPhone 14 ht...
# 1995  RT @ThetanArena: 📢 The opportunity to win an i...
# 3546  @TechnicallyTee Apple has great products but a...
#
#                                      comment_word_token
# 7848  nelli ignored started panicking got call hes t...
# 3700  freedom sell products services ease target cus...
# 8277       launch foldable rather analyst predicts cnbc
# 1218  few functions secondly critical settings requi...
# ...

# %% [markdown]
# ## Rating / Score

# %% [markdown]
# #### Polarity Rating

# %%
polarity_score = []

for text in df['comment_word_token']:
  blob = TextBlob(text)
  for sentence in blob.sentences:
    if sentence.sentiment.polarity > 0.0:
      polarity_score.append('positive')
    elif sentence.sentiment.polarity < 0.0:
      polarity_score.append('negative')
    else:
      polarity_score.append('neutral')

# %%
def senti(x):
    return TextBlob(x).sentiment.polarity
 
df['polarity_score'] = df['comment_word_token'].apply(senti)

# %%
def getAnalysis(score):
  if score < 0:
    return "Negative"
  elif score == 0:
    return "Neutral"
  else:
    return "Positive"
df['polarity_rating'] = df['polarity_score'].apply(getAnalysis)

# %%
df
# Out:
#                                                    text  \
# 3940  @olami133 Person wey load HP 180k and Iphone d...
# 3855  RT @vampireinfinite: How to Send a Text From a...
# 9472  Almost 1 Million People in Chinese City Near i...
# 5281  @od_young @ama_kodesh Joker... iPhone users an...
# 65    RT @Ahmadansari2233: ⬇️⬇️Home screen setup fo ...
# ...                                                 ...
# 6819  RT @Blacktradelines: 6 foot iPhone cable - $5....
# 7487  RT @OmuhimaGd: 3cows or an iphone 14promax \nW...
# 138   @messipropfc @uhd2020 I used a humble now “old...
# 4229  On my iPhone 8 the Monkey application starts i...
# 435   Well, @heatherkelly has tackled America's grea...
#
#                                      comment_word_token  polarity_score  \
# 3940     person wey load hp dey follow palmpay drag mad       -0.362500
# 3855  send text computer phonehowto tipster tipsandt...        0.000000
# 9472               almost chinese city factory lockdown        0.000000
# ...

# %%
temp_p = df.groupby('polarity_rating').count()['comment_word_token'].reset_index().sort_values(by='comment_word_token',ascending=False)
temp_p.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_dc05a_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_dc05a_row1_col1 {
#   background-color: #5c3797;
#   color: #f1f1f1;
# }
# #T_dc05a_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_dc05a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >polarity_rating</th>
#       <th class="col_heading level0 col1" >comment_word_token</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc05a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dc05a_row0_col0" class="data row0 col0" >Neutral</td>
#       <td id="T_dc05a_row0_col1" class="data row0 col1" >1434</td>
#     </tr>
#     <tr>
#       <th id="T_dc05a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dc05a_row1_col0" class="data row1 col0" >Positive</td>
# ...

# %% [markdown]
# #### VADER rating

# %%
# function to calculate vader sentiment
def vadersentimentanalysis(review):
    vs = analyzer.polarity_scores(review)
    return vs['compound']
    df['Vader_data'] = df['comment_word_token'].apply(vadersentimentanalysis)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
def vadar_sentiment(text):
    return analyzer.polarity_scores(text)['compound']

# create new column for vadar compound sentiment score
df['vader_compound'] = df['comment_word_token'].apply(vadar_sentiment)

def categorise_sentiment(sentiment, neg_threshold=-0.05, pos_threshold=0.05):
    if sentiment < neg_threshold:
        label = 'negative'
    elif sentiment > pos_threshold:
        label = 'positive'
    else:
        label = 'neutral'
    return label

# new col with vadar sentiment label based on vadar compound score
df['vader_score'] = df['vader_compound'].apply(categorise_sentiment)

# %%
temp_v = df.groupby('vader_score').count()['comment_word_token'].reset_index().sort_values(by='comment_word_token',ascending=False)
temp_v.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_2afea_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_2afea_row1_col1 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_2afea_row2_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_2afea_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >vader_score</th>
#       <th class="col_heading level0 col1" >comment_word_token</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2afea_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_2afea_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_2afea_row0_col1" class="data row0 col1" >1432</td>
#     </tr>
#     <tr>
#       <th id="T_2afea_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2afea_row1_col0" class="data row1 col0" >positive</td>
# ...

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
plt.title("TextBlob results")
plt.pie(temp_p.comment_word_token, labels = temp_p.polarity_rating, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
plt.subplot(1,2,2)
plt.title("VADER results")
plt.pie(temp_v.comment_word_token, labels = temp_v.vader_score, explode = (0, 0, 0.25), autopct='%1.1f%%', shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f297c104410>,
# ...
#  [Text(0.17534151402340306, 1.0859352436770717, 'neutral'),
#   Text(-0.7077578441125324, -0.8420681885080212, 'positive'),
#   Text(1.1586914502718004, -0.6927727788149819, 'negative')],
#  [Text(0.09564082583094712, 0.5923283147329481, '44.9%'),
#   Text(-0.38604973315229035, -0.4593099210043752, '37.9%'),
#   Text(0.729546468689652, -0.43619026814276635, '17.2%')])

# %%
df
# Out:
#                                                    text  \
# 3940  @olami133 Person wey load HP 180k and Iphone d...
# 3855  RT @vampireinfinite: How to Send a Text From a...
# 9472  Almost 1 Million People in Chinese City Near i...
# 5281  @od_young @ama_kodesh Joker... iPhone users an...
# 65    RT @Ahmadansari2233: ⬇️⬇️Home screen setup fo ...
# ...                                                 ...
# 6819  RT @Blacktradelines: 6 foot iPhone cable - $5....
# 7487  RT @OmuhimaGd: 3cows or an iphone 14promax \nW...
# 138   @messipropfc @uhd2020 I used a humble now “old...
# 4229  On my iPhone 8 the Monkey application starts i...
# 435   Well, @heatherkelly has tackled America's grea...
#
#                                      comment_word_token  polarity_score  \
# 3940     person wey load hp dey follow palmpay drag mad       -0.362500
# 3855  send text computer phonehowto tipster tipsandt...        0.000000
# 9472               almost chinese city factory lockdown        0.000000
# ...

# %%
df['rating'] = df['polarity_rating']
df.rating = df.rating.str.replace('Positive', '1')
df.rating = df.rating.str.replace('Neutral', '0')
df.rating = df.rating.str.replace('Negative', '-1')

# %% [markdown]
# ### Wordcloud

# %%
import imageio
# add picture
pic = imageio.imread('/content/drive/MyDrive/Colab Notebooks/733635.png')

data_pos = df.loc[df['polarity_rating'] == 'Positive']['comment_word_token']

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate(" ".join(data_pos))

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Positive word that affect sentimental result")
plt.show()

# %%
data_nega = df.loc[df['polarity_rating'] == 'Negative']['comment_word_token']

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate(" ".join(data_nega))

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Negative word that affect sentimental result")
plt.show()

# %%
data_neu = df.loc[df['polarity_rating'] == 'Neutral']['comment_word_token']

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate(" ".join(data_neu))

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Neutral word that affect sentimental result")
plt.show()

# %% [markdown]
# ### TF - IDF

# %%
vectorizer = TfidfVectorizer()

# %%
train_data_features = vectorizer.fit_transform(df['comment_word_token'])
print(train_data_features.shape)
# Out:
# (3189, 8283)

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True) 
tfidf_transformer.fit(train_data_features)
# Out:
# TfidfTransformer()

# %%
# print idf values 
df_idf = pd.DataFrame(tfidf_transformer.idf_, index=vectorizer.get_feature_names(),columns=["idf_weights"]) 
# sort ascending 
df_idf.sort_values(by=['idf_weights']).head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#        idf_weights
# new       3.587137
# get       3.847420
# use       4.140523
# dont      4.271986
# still     4.358246

# %%
# count matrix 
count_vector=vectorizer.transform(df['comment_word_token']) 
# tf-idf scores 
tf_idf_vector=tfidf_transformer.transform(count_vector)

# %%
feature_names = vectorizer.get_feature_names() 
#get tfidf vector for first document 
first_document_vector=tf_idf_vector[0] 
#print the scores 
df_idf = pd.DataFrame(first_document_vector.T.todense(), index=feature_names, columns=["tfidf"]) 
df_idf.sort_values(by=["tfidf"],ascending=False).head()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#             tfidf
# drag     0.448109
# palmpay  0.448109
# hp       0.405768
# load     0.377001
# mad      0.338251

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Learning algorithm

# %%
# We split train dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_data_features, df['rating'], test_size=0.2, random_state=42)

# %%
# We train 4 models: random forest, multinomial logistic regression (Softmax Regression),and SVM
from sklearn.ensemble import RandomForestClassifier
# Initialize a Random Forest classifier with 500 trees
forest = RandomForestClassifier(n_estimators = 500, max_depth = None, min_samples_split=2, min_samples_leaf =1,
                                bootstrap = True, random_state=0)
# Train the model
forest = forest.fit(X_train, y_train)
# Print score of model(using test dataset)
print(forest.score(X_test, y_test))
# Out:
# 0.8275862068965517

# %%
from sklearn.linear_model import LogisticRegression
# Initialize a logistic regression model 
logistic = LogisticRegression(solver ='lbfgs', multi_class='multinomial')
# Train the model
logistic = logistic.fit(X_train, y_train)
# Print score of model(using test dataset)
print(logistic.score(X_test, y_test))
# Out:
# 0.7429467084639498

# %% [markdown]
# Using RBF Kennal due to the relation between a variable depends on its neighbor

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB().fit(X_train, y_train)
print(mnb.score(X_test, y_test))
# Out:
# 0.7210031347962382

# %%
y_pred_forest = forest.predict(X_test)
y_pred_logistic = logistic.predict(X_test)
y_pred_mnb = mnb.predict(X_test)

# %% [markdown]
# ## Confusion matrix

# %% [markdown]
# ### Random Forest

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix_forest = confusion_matrix(y_test, y_pred_forest, labels=['1','0','-1'])
confusion_matrix_forest

import seaborn as sns
# plot the confusion matrix
ax = plt.axes()
sns.heatmap(confusion_matrix_forest, annot=True,fmt="d",cmap='Blues')
ax.set_title('Confusion matrix Random Forest')
ax.set_xlabel('Predicted values')
ax.set_ylabel('True values')
ax.xaxis.set_ticklabels(['Positive','Neutral','Negative']);
ax.yaxis.set_ticklabels(['Positive','Neutral','Negative']);

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_forest))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.90      0.48      0.62        92
#            0       0.75      0.99      0.85       280
#            1       0.93      0.78      0.85       266
#
#     accuracy                           0.83       638
#    macro avg       0.86      0.75      0.78       638
# weighted avg       0.85      0.83      0.82       638

# %% [markdown]
# ### Logistic Regression

# %%
confusion_matrix_logistic = confusion_matrix(y_test, y_pred_logistic, labels=['1','0','-1'])
confusion_matrix_logistic

import seaborn as sns
# plot the confusion matrix
ax = plt.axes()
sns.heatmap(confusion_matrix_logistic, annot=True, fmt="d",cmap='Blues')
ax.set_title('Confusion matrix Logistic Regression')
ax.set_xlabel('Predicted values')
ax.set_ylabel('True values')
ax.xaxis.set_ticklabels(['Positive','Neutral','Negative']);
ax.yaxis.set_ticklabels(['Positive','Neutral','Negative']);

# %%
print(classification_report(y_test, y_pred_logistic))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.17      0.30        92
#            0       0.65      0.97      0.78       280
#            1       0.90      0.70      0.79       266
#
#     accuracy                           0.74       638
#    macro avg       0.85      0.61      0.62       638
# weighted avg       0.81      0.74      0.71       638

# %% [markdown]
# ### Naive Bayve

# %%
confusion_matrix_mnb = confusion_matrix(y_test, y_pred_mnb, labels=['1','0','-1'])
confusion_matrix_mnb

import seaborn as sns
# plot the confusion matrix
ax = plt.axes()
sns.heatmap(confusion_matrix_mnb, annot=True, fmt="d",cmap='Blues')
ax.set_title('Confusion matrix Decision Tree')
ax.set_xlabel('Predicted values')
ax.set_ylabel('True values')
ax.xaxis.set_ticklabels(['Positive','Neutral','Negative']);
ax.yaxis.set_ticklabels(['Positive','Neutral','Negative']);

# %%
print(classification_report(y_test, y_pred_mnb))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      0.12      0.21        92
#            0       0.72      0.82      0.77       280
#            1       0.72      0.82      0.77       266
#
#     accuracy                           0.72       638
#    macro avg       0.81      0.59      0.58       638
# weighted avg       0.76      0.72      0.69       638

# %% [markdown]
# ## Applying ML to test database

# %%
# Create an empty list and append the clean reviews one by one
num_reviews = len(df_test["text"])
test_data_features = [] 

# Create the test set with the words encoded as features of the reviews
test_data_features = vectorizer.transform(df_test['comment_word_token'])


# Use the logistic regression model to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and a "sentiment" column
output = pd.DataFrame( data={"text":df_test["text"], "sentiment":result} )

# %%
output.sentiment.value_counts()
# Out:
# 0     446
# 1     285
# -1     67
# Name: sentiment, dtype: int64

# %%
output.shape
# Out:
# (798, 2)

# %% [markdown]
# # Visualize Result

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/TwtAPI.xlsx')

# %%
# Create an empty list and append the clean reviews one by one
num_reviews = len(df["text"])
test_data_features = [] 

# Create the test set with the words encoded as features of the reviews
test_data_features = vectorizer.transform(df['text'])

# Vader score
score = df['text'].apply(vadar_sentiment)

# Use the logistic regression model to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and a "sentiment" column
df = pd.DataFrame( data={"text":df["text"], "verified":df["user_verified"] , "time":df["date"] , "score":score, "location":df['user_location']} )

# %%
def getAnalysis(score):
  if score < 0:
    return "Negative"
  elif score == 0:
    return "Neutral"
  else:
    return "Positive"
df['sentiment'] = df['score'].apply(getAnalysis)

# %% [markdown]
# The number of comment in language

# %%
df
# Out:
#                                                    text  verified  \
# 0     RT @MacMallyMMA: The iPhone 14 Pro Max camera ...     False
# 1     RT @discount77777: Get Free iPhone Giveaway ht...     False
# 2     RT @amazonIN: Hurry! The #AmazonGreatIndianFes...     False
# 3     RT @shopapplegh: We have these in stock today....     False
# 4     RT @MuneerahSuraj: Customized phone cases:\nSa...     False
# ...                                                 ...       ...
# 9995  RT @CurrenSy_Spitta: If I had an iPhone with g...     False
# 9996  RT @EbukaIsaac26: Johnny Drille and Don Jazzy ...     False
# 9997  RT @Crunchyroll: w00t apple just announced the...     False
# 9998  Have you been searching for the best corporate...     False
# 9999  RT @bidemi42: Dear Nigerians.\npls help retwee...     False
#
#                     time   score                   location sentiment
# 0    2022-10-19 11:24:55 -0.4639                        NaN  Negative
# ...

# %%
df['text']=df['text'].apply(cleanTxt)

# %%
df['text'] = df['text'].apply(lambda x : x.lower())

# %%
df['text'] = df['text'].apply(lambda x: lookup_dict(x,apostrophe_dict))
df['text'] = df['text'].apply(lambda x: lookup_dict(x,icon_lib))
df['text'] = df['text'].apply(lambda x: lookup_dict(x,short_word_dict))

# %%
df['tweet_token'] = df['text'].apply(lambda x: word_tokenize(x))
df['tweet_token'] = df['tweet_token'].apply(lambda x: [word for word in x if not word in stop])
df['tagged'] = df['tweet_token'].apply(nltk.pos_tag)
df['text_clean'] = df['tagged'].apply(lambda x: [word for word, tag in x if tag in ['NN', 'NNS','VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ','RB','RBR','RBS','MD','JJ','JJR','JJS','PDT','RP','UH','WDT','WRB','WP']])

# %%
df['text_clean'] = df['text_clean'].apply(lambda x: ' '.join([lemmatizer.lemmatize(i,pos="a") for i in x]))
more_stop = ['iphone','pro','max','phone','apple','people','x','xs','xr','samsung','twitter','ipad','todayiphone','franceswedennorwaydenmarkaustralia','amazongreatindianfestival','s10s10s20s20n3500iphone','casessamsung','seriesn3500','n3500','promax','xsmax','iphone14pro','iphone14promax','iphone14','askurvashi','jerusalem','imran','khanballondorbtsarmy','android','wallpapers','truvybe','truvyberadio','app','amp','im','cybernipo','etsyseller','io','wed','oct','camera','user','users','video','way','ios','radio','mobile']
df['text_clean'] = df['text_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (more_stop)]))

# %%
df = df.drop(['tweet_token','tagged'], axis=1)
df['text_clean'] = df['text_clean'].apply(lambda x: word_tokenize(x))

# %%
df
# Out:
#                                                    text  verified  \
# 0     the iphone 14 pro max camera is garbage makes ...     False
# 1     get free iphone giveaway only people of france...     False
# 2     hurry the amazongreatindianfestival is ending ...     False
# 3     we have these in stock todayiphone 13 pro and ...     False
# 4     customized phone casessamsung s10s10s20s20n350...     False
# ...                                                 ...       ...
# 9995  spitta if i had an iphone with google as a chi...     False
# 9996  johnny drille and don jazzy melt the hearts of...     False
# 9997  w00t apple just announced the iphone 3gs  on j...     False
# 9998  have you been searching for the best corporate...     False
# 9999  dear nigerianspls help retweet my hustle 18kwh...     False
#
#                     time   score                   location sentiment  \
# 0    2022-10-19 11:24:55 -0.4639                        NaN  Negative
# ...

# %% [markdown]
# ## Positive

# %%
df_p = df.loc[df['sentiment'] == 'Positive']

# %%
df_p
# Out:
#                                                    text  verified  \
# 1     get free iphone giveaway only people of france...     False
# 2     hurry the amazongreatindianfestival is ending ...     False
# 6                                        i love iphone      False
# 8     my 3rd international smartphone giveaway has o...     False
# 9     anyone want a 129 ipad pro i will be giving on...     False
# ...                                                 ...       ...
# 9991  with the  you have the freedom to sell like ne...     False
# 9996  johnny drille and don jazzy melt the hearts of...     False
# 9997  w00t apple just announced the iphone 3gs  on j...     False
# 9998  have you been searching for the best corporate...     False
# 9999  dear nigerianspls help retweet my hustle 18kwh...     False
#
#                     time   score                   location sentiment  \
# 1    2022-10-19 11:24:50  0.5106                        NaN  Positive
# ...

# %%
top = Counter([item for sublist in df_p['text_clean'] for item in sublist])
temp_positive = pd.DataFrame.from_dict(top, orient='index').reset_index()
temp_positive = temp_positive.rename(columns={'index':'word', 0:'count'})
temp_positive.sort_values('count',ascending=False,).head(10).style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_ec256_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ec256_row1_col1 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_ec256_row2_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_ec256_row3_col1 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_ec256_row4_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_ec256_row5_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_ec256_row6_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_ec256_row7_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_ec256_row8_col1, #T_ec256_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_ec256_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >word</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
# ...

# %%
import plotly.express as px

fig = px.bar(temp_positive.sort_values('count',ascending=False,).head(15), x="count", y="word", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate_from_frequencies(top)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Common positive words around iPhone release")
plt.show()

# %% [markdown]
# ## Negative

# %%
df_n = df.loc[df['sentiment'] == 'Negative']

# %%
df_n
# Out:
#                                                    text  verified  \
# 0     the iphone 14 pro max camera is garbage makes ...     False
# 5        mashudum symptoms of forcing things 1 iphone 6     False
# 11    we were today years old when we learned this i...     False
# 13    the iphone 14 notch is so fucking ugly laugh m...     False
# 17    cellphone technology peaked when flip phones c...     False
# ...                                                 ...       ...
# 9961  piq  newsquawks euro market open mixed trade a...     False
# 9966  police suppose dey arrest people wey still dey...     False
# 9967    an iphone ordered on 2nd oct  using and canc...     False
# 9979  accounts the money was transferred to unless i...     False
# 9986  isart sadly apples oath for the saving environ...     False
#
#                     time   score              location sentiment  \
# 0    2022-10-19 11:24:55 -0.4639                   NaN  Negative
# ...

# %%
top_n = Counter([item for sublist in df_n['text_clean'] for item in sublist])
temp_negative = pd.DataFrame.from_dict(top_n, orient='index').reset_index()
temp_negative = temp_negative.rename(columns={'index':'word', 0:'count'})
temp_negative.sort_values('count',ascending=False,).head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_67aaa_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_67aaa_row1_col1 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_67aaa_row2_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_67aaa_row3_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_67aaa_row4_col1 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_67aaa_row5_col1 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_67aaa_row6_col1 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_67aaa_row7_col1 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_67aaa_row8_col1 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_67aaa_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_67aaa_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >word</th>
# ...

# %%
fig = px.bar(temp_negative.sort_values('count',ascending=False,).head(15), x="count", y="word", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate_from_frequencies(top_n)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Common negative words around iPhone release")
plt.show()

# %% [markdown]
# ## Neutral

# %%
df_ne = df.loc[df['sentiment'] == 'Neutral']

# %%
df_ne
# Out:
#                                                    text  verified  \
# 3     we have these in stock todayiphone 13 pro and ...     False
# 4     customized phone casessamsung s10s10s20s20n350...     False
# 7     dubai mall iphone 14 pro 512gb gold is not ava...     False
# 10    210 on ipad and iphone millions of new artists...      True
# 12    iphone 12                          iphone 14 p...     False
# ...                                                 ...       ...
# 9988         i have the sudden urge to buy an iphone 5c     False
# 9992                                       3dayo iphone     False
# 9993  chengula iphone 12 pro max128gb 2100000 256gb ...     False
# 9994  chengula iphone 12 pro max128gb 2100000 256gb ...     False
# 9995  spitta if i had an iphone with google as a chi...     False
#
#                     time  score           location sentiment  \
# 3    2022-10-19 11:24:45    0.0                NaN   Neutral
# ...

# %%
top_ne = Counter([item for sublist in df_ne['text_clean'] for item in sublist])
temp_neutral = pd.DataFrame.from_dict(top_ne, orient='index').reset_index()
temp_neutral = temp_neutral.rename(columns={'index':'word', 0:'count'})
temp_neutral.sort_values('count',ascending=False,).head(10).style.background_gradient(cmap='Greys')
# Out:
# <style type="text/css">
# #T_4e4e5_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_4e4e5_row1_col1 {
#   background-color: #030303;
#   color: #f1f1f1;
# }
# #T_4e4e5_row2_col1 {
#   background-color: #a8a8a8;
#   color: #f1f1f1;
# }
# #T_4e4e5_row3_col1 {
#   background-color: #dddddd;
#   color: #000000;
# }
# #T_4e4e5_row4_col1 {
#   background-color: #f1f1f1;
#   color: #000000;
# }
# #T_4e4e5_row5_col1, #T_4e4e5_row6_col1 {
#   background-color: #f3f3f3;
#   color: #000000;
# }
# #T_4e4e5_row7_col1, #T_4e4e5_row8_col1 {
#   background-color: #fcfcfc;
#   color: #000000;
# }
# #T_4e4e5_row9_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# </style>
# <table id="T_4e4e5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >word</th>
#       <th class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
fig = px.bar(temp_neutral.sort_values('count',ascending=False,).head(15), x="count", y="word", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,mask=pic,background_color ='white').generate_from_frequencies(top_ne)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Common neutral words around iPhone release")
plt.show()

# %% [markdown]
# # Fuzzy model

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
result = df['text_clean'].sample()
print(result)
# Out:
# 9155    [join, start, making, cool, cash, odds, odds, ...

# %%
result = result.to_string()

# %%
v = SentimentIntensityAnalyzer()
res = v.polarity_scores(result)

# %%
v.polarity_scores(result)
# Out:
# {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.5423}

# %%
posscore=res['pos']
negscore=res['neg']
neuscore=res['neu']
compoundscore=res['compound']

# %%
print("\nPositive Score :")    
if (posscore==1):
    posscore=0.9 
else:
    posscore=round(posscore,1)
print(posscore)

print("\nNegative Score :")
if (negscore==1):
    negscore=0.9
else:
    negscore=round(negscore,1)
print(negscore)
# Out:
# Positive Score :
# 0.4
#
# Negative Score :
# 0.0

# %%
# Generate universe variables
#   * pos and neg on subjective ranges [0, 1]
#   * op has a range of [0, 10] in units of percentage points
x_p = np.arange(0, 1, 0.1)
x_n = np.arange(0, 1, 0.1)
x_op = np.arange(0, 10, 1)

# %%
# Generate fuzzy membership functions
p_lo = fuzz.trimf(x_p, [0, 0, 0.5])
p_md = fuzz.trimf(x_p, [0, 0.5, 1])
p_hi = fuzz.trimf(x_p, [0.5, 1, 1])
n_lo = fuzz.trimf(x_n, [0, 0, 0.5])
n_md = fuzz.trimf(x_n, [0, 0.5, 1])
n_hi = fuzz.trimf(x_n, [0.5, 1, 1])
op_Neg = fuzz.trimf(x_op, [0, 0, 5])  # Scale : Neg Neu Pos
op_Neu = fuzz.trimf(x_op, [0, 5, 10])
op_Pos = fuzz.trimf(x_op, [5, 10, 10])

# %%
# Visualize these universes and membership functions
fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8, 9))
#
ax0.plot(x_p, p_lo, 'b', linewidth=1.5, label='Low')
ax0.plot(x_p, p_md, 'g', linewidth=1.5, label='Medium')
ax0.plot(x_p, p_hi, 'r', linewidth=1.5, label='High')
ax0.set_title('Pos')
ax0.legend()

ax1.plot(x_n, n_lo, 'b', linewidth=1.5, label='Low')
ax1.plot(x_n, n_md, 'g', linewidth=1.5, label='Medium')
ax1.plot(x_n, n_hi, 'r', linewidth=1.5, label='High')
ax1.set_title('Neg')
ax1.legend()

ax2.plot(x_op, op_Pos, 'b', linewidth=1.5, label='Negative')
ax2.plot(x_op, op_Neu, 'g', linewidth=1.5, label='Neutral')
ax2.plot(x_op, op_Neg, 'r', linewidth=1.5, label='Positive')
ax2.set_title('Output')
ax2.legend()

# %%
sentiment=[]
sentiment_doc=[]

# %%
# We need the activation of our fuzzy membership functions at these values.
p_level_lo = fuzz.interp_membership(x_p, p_lo, posscore)
p_level_md = fuzz.interp_membership(x_p, p_md, posscore)
p_level_hi = fuzz.interp_membership(x_p, p_hi, posscore)
    
n_level_lo = fuzz.interp_membership(x_n, n_lo, negscore)
n_level_md = fuzz.interp_membership(x_n, n_md, negscore)
n_level_hi = fuzz.interp_membership(x_n, n_hi, negscore)
#defining rules
active_rule1 = np.fmin(p_level_lo, n_level_lo)
active_rule2 = np.fmin(p_level_md, n_level_lo)
active_rule3 = np.fmin(p_level_hi, n_level_lo)
active_rule4 = np.fmin(p_level_lo, n_level_md)
active_rule5 = np.fmin(p_level_md, n_level_md)
active_rule6 = np.fmin(p_level_hi, n_level_md)
active_rule7 = np.fmin(p_level_lo, n_level_hi)
active_rule8 = np.fmin(p_level_md, n_level_hi)
active_rule9 = np.fmin(p_level_hi, n_level_hi)
# Now we apply this by clipping the top off the corresponding output
# membership function with `np.fmin`
    
n1=np.fmax(active_rule4,active_rule7)
n2=np.fmax(n1,active_rule8)     
op_activation_lo = np.fmin(n2,op_Neg)
    
neu1=np.fmax(active_rule1,active_rule5)
neu2=np.fmax(neu1,active_rule9)     
op_activation_md = np.fmin(neu2,op_Neu)
    
p1=np.fmax(active_rule2,active_rule3)
p2=np.fmax(p1,active_rule6)   
op_activation_hi = np.fmin(p2,op_Pos)
    
op0 = np.zeros_like(x_op)
# Aggregate all three output membership functions together
aggregated = np.fmax(op_activation_lo,np.fmax(op_activation_md, op_activation_hi))
# Calculate defuzzified result
op = fuzz.defuzz(x_op, aggregated, 'centroid')
output=round(op,2)

op_activation = fuzz.interp_membership(x_op, aggregated, op)

# %%
# Visualize Output Membership
fig, ax0 = plt.subplots(figsize=(8, 3))
    
ax0.fill_between(x_op, op0, op_activation_lo, facecolor='b', alpha=0.7)
ax0.plot(x_op, op_Neg, 'b', linewidth=0.5, linestyle='--',label= 'Negative' )
ax0.fill_between(x_op, op0, op_activation_md, facecolor='g', alpha=0.7)
ax0.plot(x_op, op_Neu, 'g', linewidth=0.5, linestyle='--', label='Neutral')
ax0.fill_between(x_op, op0, op_activation_hi, facecolor='r', alpha=0.7)
ax0.plot(x_op, op_Pos, 'r', linewidth=0.5, linestyle='--', label='Positive')
ax0.plot([op, op], [0, op_activation], 'k', linewidth=1.5, alpha=0.9)
ax0.set_title('Output membership activity')
ax0.legend()

# %% [markdown]
# # Export

# %%
df.to_excel('rating.xlsx')
files.download('rating.xlsx')
